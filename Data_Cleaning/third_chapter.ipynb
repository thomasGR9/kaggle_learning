# %%
import pandas as pd
import numpy as np
import seaborn as sns
import datetime
import matplotlib.pyplot as plt


landslides = pd.read_csv("./catalog.csv")


np.random.seed(0)

# %%
landslides
# Out:
#         id     date   time continent_code   country_name country_code  \
# 0       34   3/2/07  Night            NaN  United States           US
# 1       42  3/22/07    NaN            NaN  United States           US
# 2       56   4/6/07    NaN            NaN  United States           US
# 3       59  4/14/07    NaN            NaN         Canada           CA
# 4       61  4/15/07    NaN            NaN  United States           US
# ...    ...      ...    ...            ...            ...          ...
# 1688  7535  12/7/15    NaN            NaN  United States           US
# 1689  7537  2/22/16   0:00            NaN  United States           US
# 1690  7539  2/23/16    NaN            NaN  United States           US
# 1691  7540  2/26/16  21:06            NaN  United States           US
# 1692  7541   3/2/16   8:00            NaN  United States           US
#
#       state/province  population         city/town  distance  ...  \
# ...

# %%
print(landslides['date'].head())
# Out:
# 0     3/2/07
# 1    3/22/07
# 2     4/6/07
# 3    4/14/07
# 4    4/15/07
# Name: date, dtype: object

# %%
landslides['date_parsed'] = pd.to_datetime(landslides['date'], format='%m/%d/%y')

# %%
landslides['date_parsed']
# Out:
# 0      2007-03-02
# 1      2007-03-22
# 2      2007-04-06
# 3      2007-04-14
# 4      2007-04-15
#           ...
# 1688   2015-12-07
# 1689   2016-02-22
# 1690   2016-02-23
# 1691   2016-02-26
# 1692   2016-03-02
# Name: date_parsed, Length: 1693, dtype: datetime64[ns]

# %%
day_of_month_landslides = landslides['date_parsed'].dt.day
day_of_month_landslides.head()
# Out:
# 0     2.0
# 1    22.0
# 2     6.0
# 3    14.0
# 4    15.0
# Name: date_parsed, dtype: float64

# %%
day_of_month_landslides = day_of_month_landslides.dropna()
sns.displot(day_of_month_landslides, kde=False, bins=31)

# %%
earthquakes = pd.read_csv('./database.csv')
earthquakes
# Out:
#              Date      Time  Latitude  Longitude        Type   Depth  \
# 0      01/02/1965  13:44:18   19.2460   145.6160  Earthquake  131.60
# 1      01/04/1965  11:29:49    1.8630   127.3520  Earthquake   80.00
# 2      01/05/1965  18:05:58  -20.5790  -173.9720  Earthquake   20.00
# 3      01/08/1965  18:49:43  -59.0760   -23.5570  Earthquake   15.00
# 4      01/09/1965  13:32:50   11.9380   126.4270  Earthquake   15.00
# ...           ...       ...       ...        ...         ...     ...
# 23407  12/28/2016  08:22:12   38.3917  -118.8941  Earthquake   12.30
# 23408  12/28/2016  09:13:47   38.3777  -118.8957  Earthquake    8.80
# 23409  12/28/2016  12:38:51   36.9179   140.4262  Earthquake   10.00
# 23410  12/29/2016  22:30:19   -9.0283   118.6639  Earthquake   79.00
# 23411  12/30/2016  20:08:28   37.3973   141.4103  Earthquake   11.94
#
#        Depth Error  Depth Seismic Stations  Magnitude Magnitude Type  ...  \
# ...

# %%
np.random.seed(0)

# %%
earthquakes.Date
# Out:
# 0        01/02/1965
# 1        01/04/1965
# 2        01/05/1965
# 3        01/08/1965
# 4        01/09/1965
#             ...
# 23407    12/28/2016
# 23408    12/28/2016
# 23409    12/28/2016
# 23410    12/29/2016
# 23411    12/30/2016
# Name: Date, Length: 23412, dtype: object

# %%
date_lengths = earthquakes.Date.str.len()
date_lengths.value_counts()
# Out:
# 10    23409
# 24        3
# Name: Date, dtype: int64

# %%
earthquakes.loc[date_lengths == 24]['Date'] ==
# Out:
# 3378     1975-02-23T02:58:41.000Z
# 7512     1985-04-28T02:53:41.530Z
# 20650    2011-03-13T02:23:34.520Z
# Name: Date, dtype: object

# %%
earthquakes.loc[date_lengths == 24]['Date'].str.split('T').iloc[2][0]
# Out:
# '2011-03-13'

# %%
earthquakes.loc[date_lengths == 24]['Date'].index
# Out:
# Int64Index([3378, 7512, 20650], dtype='int64')

# %%
earthquakes['troll'] = 5

# %%
X = [1, 2, 3]
for i in [0, 1, 2]:
    X[i] = earthquakes.loc[date_lengths == 24]['Date'].str.split('T').iloc[i][0]

X
# Out:
# ['1975-02-23', '1985-04-28', '2011-03-13']

# %%
earthquakes['troll'].loc[earthquakes.loc[date_lengths == 24]['Date'].index] = X
earthquakes['troll'].loc[earthquakes.loc[date_lengths != 24]['Date'].index] = earthquakes['Date']

# %%
earthquakes['troll'].str.len().value_counts()
# Out:
# 10    23412
# Name: troll, dtype: int64

# %%
earthquakes['troll']
# Out:
# 0        01/02/1965
# 1        01/04/1965
# 2        01/05/1965
# 3        01/08/1965
# 4        01/09/1965
#             ...
# 23407    12/28/2016
# 23408    12/28/2016
# 23409    12/28/2016
# 23410    12/29/2016
# 23411    12/30/2016
# Name: troll, Length: 23412, dtype: object

# %%
earthquakes['date_parsed'] = pd.to_datetime(earthquakes['troll'], format='%m/%d/%Y', infer_datetime_format=True)

# %%
day_of_month_earthquakes = earthquakes['date_parsed'].dt.day

# %%
day_of_month_earthquakes = day_of_month_earthquakes.dropna()


sns.distplot(day_of_month_earthquakes, kde=False, bins=31)
plt.show()
# Out:
# /home/thomas/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
