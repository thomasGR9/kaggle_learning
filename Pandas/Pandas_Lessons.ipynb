# %%
import pandas as pd
pd.set_option('display.max_rows', 5)

# %%
fruits = pd.DataFrame({'Apples' : [30], 'Bananas' : [21]})
fruits
# Out:
#    Apples  Bananas
# 0      30       21

# %%
fruit_sales = pd.DataFrame({'Apples': [35, 41], 'Bananas': [21, 34]}, index={'2017 Sales', '2018 Sales'})
fruit_sales
# Out:
#             Apples  Bananas
# 2017 Sales      35       21
# 2018 Sales      41       34

# %%
ingredients = pd.Series(['4 cups', '1 cup', '2 large', '1 can'], index=['Flour', 'Milk', 'Eggs', 'Spam'], name='Dinner')
ingredients
# Out:
# Flour     4 cups
# Milk       1 cup
# Eggs     2 large
# Spam       1 can
# Name: Dinner, dtype: object

# %%
animals = pd.DataFrame({"Cows": [12, 20], "Goats": [22, 19]}, index=['Year 1', 'Year 2'])
animals
# Out:
#         Cows  Goats
# Year 1    12     22
# Year 2    20     19

# %%
animals.to_csv('cows_and_goats.csv')

# %%
reviews = pd.read_csv('./winemag-data_first150k.csv')
reviews
# Out:
#         Unnamed: 0 country                                        description  \
# 0                0      US  This tremendous 100% varietal wine hails from ...
# 1                1   Spain  Ripe aromas of fig, blackberry and cassis are ...
# ...            ...     ...                                                ...
# 150928      150928  France  A perfect salmon shade, with scents of peaches...
# 150929      150929   Italy  More Pinot Grigios should taste like this. A r...
#
#                                  designation  points  price  \
# 0                          Martha's Vineyard      96  235.0
# 1       Carodorum Selección Especial Reserva      96  110.0
# ...                                      ...     ...    ...
# 150928                       Grand Brut Rosé      90   52.0
# 150929                                   NaN      90   15.0
#
#                   province     region_1 region_2             variety  \
# ...

# %%
reviews = pd.read_csv('./winemag-data_first150k.csv', index_col='Unnamed: 0')
reviews
# Out:
#        country                                        description  \
# 0           US  This tremendous 100% varietal wine hails from ...
# 1        Spain  Ripe aromas of fig, blackberry and cassis are ...
# ...        ...                                                ...
# 150928  France  A perfect salmon shade, with scents of peaches...
# 150929   Italy  More Pinot Grigios should taste like this. A r...
#
#                                  designation  points  price  \
# 0                          Martha's Vineyard      96  235.0
# 1       Carodorum Selección Especial Reserva      96  110.0
# ...                                      ...     ...    ...
# 150928                       Grand Brut Rosé      90   52.0
# 150929                                   NaN      90   15.0
#
#                   province     region_1 region_2             variety  \
# 0               California  Napa Valley     Napa  Cabernet Sauvignon
# ...

# %%
reviews.country
# Out:
# 0             US
# 1          Spain
#            ...
# 150928    France
# 150929     Italy
# Name: country, Length: 150930, dtype: object

# %%
reviews['country']
# Out:
# 0             US
# 1          Spain
#            ...
# 150928    France
# 150929     Italy
# Name: country, Length: 150930, dtype: object

# %%
reviews['country'][0]
# Out:
# 'US'

# %%
reviews.iloc[0]
# Out:
# country                                                       US
# description    This tremendous 100% varietal wine hails from ...
#                                      ...
# variety                                       Cabernet Sauvignon
# winery                                                     Heitz
# Name: 0, Length: 10, dtype: object

# %%
reviews.iloc[:, 0]
# Out:
# 0             US
# 1          Spain
#            ...
# 150928    France
# 150929     Italy
# Name: country, Length: 150930, dtype: object

# %%
reviews.iloc[:3, 0]
# Out:
# 0       US
# 1    Spain
# 2       US
# Name: country, dtype: object

# %%
reviews.iloc[1:3, 0]
# Out:
# 1    Spain
# 2       US
# Name: country, dtype: object

# %%
reviews.iloc[[0, 1, 2], 0]
# Out:
# 0       US
# 1    Spain
# 2       US
# Name: country, dtype: object

# %%
reviews.iloc[-5:]
# Out:
#        country                                        description  \
# 150925   Italy  Many people feel Fiano represents southern Ita...
# 150926  France  Offers an intriguing nose with ginger, lime an...
# 150927   Italy  This classic example comes from a cru vineyard...
# 150928  France  A perfect salmon shade, with scents of peaches...
# 150929   Italy  More Pinot Grigios should taste like this. A r...
#
#             designation  points  price            province           region_1  \
# 150925              NaN      91   20.0      Southern Italy  Fiano di Avellino
# 150926   Cuvée Prestige      91   27.0           Champagne          Champagne
# 150927    Terre di Dora      91   20.0      Southern Italy  Fiano di Avellino
# 150928  Grand Brut Rosé      90   52.0           Champagne          Champagne
# 150929              NaN      90   15.0  Northeastern Italy         Alto Adige
#
#        region_2          variety                 winery
# ...

# %%
reviews.loc[0, 'country']
# Out:
# 'US'

# %%
reviews.loc[:, ['price', 'points']]
# Out:
#         price  points
# 0       235.0      96
# 1       110.0      96
# ...       ...     ...
# 150928   52.0      90
# 150929   15.0      90
#
# [150930 rows x 2 columns]

# %%
reviews.set_index("variety")
# Out:
#                    country                                        description  \
# variety
# Cabernet Sauvignon      US  This tremendous 100% varietal wine hails from ...
# Tinta de Toro        Spain  Ripe aromas of fig, blackberry and cassis are ...
# ...                    ...                                                ...
# Champagne Blend     France  A perfect salmon shade, with scents of peaches...
# Pinot Grigio         Italy  More Pinot Grigios should taste like this. A r...
#
#                                              designation  points  price  \
# variety
# Cabernet Sauvignon                     Martha's Vineyard      96  235.0
# Tinta de Toro       Carodorum Selección Especial Reserva      96  110.0
# ...                                                  ...     ...    ...
# Champagne Blend                          Grand Brut Rosé      90   52.0
# Pinot Grigio                                         NaN      90   15.0
#
# ...

# %%
reviews['country'] == 'Italy'
# Out:
# 0         False
# 1         False
#           ...
# 150928    False
# 150929     True
# Name: country, Length: 150930, dtype: bool

# %%
reviews.loc[reviews['country'] == 'Italy']
# Out:
#        country                                        description  \
# 10       Italy  Elegance, complexity and structure come togeth...
# 32       Italy  Underbrush, scorched earth, menthol and plum s...
# ...        ...                                                ...
# 150927   Italy  This classic example comes from a cru vineyard...
# 150929   Italy  More Pinot Grigios should taste like this. A r...
#
#                designation  points  price            province  \
# 10      Ronco della Chiesa      95   80.0  Northeastern Italy
# 32           Vigna Piaggia      90    NaN             Tuscany
# ...                    ...     ...    ...                 ...
# 150927       Terre di Dora      91   20.0      Southern Italy
# 150929                 NaN      90   15.0  Northeastern Italy
#
#                       region_1 region_2       variety            winery
# 10                      Collio      NaN      Friulano  Borgo del Tiglio
# ...

# %%
reviews.loc[(reviews['country'] == 'Italy') & (reviews['points'] >= 90)]
# Out:
#        country                                        description  \
# 10       Italy  Elegance, complexity and structure come togeth...
# 32       Italy  Underbrush, scorched earth, menthol and plum s...
# ...        ...                                                ...
# 150927   Italy  This classic example comes from a cru vineyard...
# 150929   Italy  More Pinot Grigios should taste like this. A r...
#
#                designation  points  price            province  \
# 10      Ronco della Chiesa      95   80.0  Northeastern Italy
# 32           Vigna Piaggia      90    NaN             Tuscany
# ...                    ...     ...    ...                 ...
# 150927       Terre di Dora      91   20.0      Southern Italy
# 150929                 NaN      90   15.0  Northeastern Italy
#
#                       region_1 region_2       variety            winery
# 10                      Collio      NaN      Friulano  Borgo del Tiglio
# ...

# %%
reviews.loc[(reviews['country'] == 'Italy') | (reviews['points'] >= 90)]
# Out:
#        country                                        description  \
# 0           US  This tremendous 100% varietal wine hails from ...
# 1        Spain  Ripe aromas of fig, blackberry and cassis are ...
# ...        ...                                                ...
# 150928  France  A perfect salmon shade, with scents of peaches...
# 150929   Italy  More Pinot Grigios should taste like this. A r...
#
#                                  designation  points  price  \
# 0                          Martha's Vineyard      96  235.0
# 1       Carodorum Selección Especial Reserva      96  110.0
# ...                                      ...     ...    ...
# 150928                       Grand Brut Rosé      90   52.0
# 150929                                   NaN      90   15.0
#
#                   province     region_1 region_2             variety  \
# 0               California  Napa Valley     Napa  Cabernet Sauvignon
# ...

# %%
reviews.loc[reviews.country.isin(['Italy', 'France'])]
# Out:
#        country                                        description  \
# 4       France  This is the top wine from La Bégude, named aft...
# 10       Italy  Elegance, complexity and structure come togeth...
# ...        ...                                                ...
# 150928  France  A perfect salmon shade, with scents of peaches...
# 150929   Italy  More Pinot Grigios should taste like this. A r...
#
#                designation  points  price            province    region_1  \
# 4               La Brûlade      95   66.0            Provence      Bandol
# 10      Ronco della Chiesa      95   80.0  Northeastern Italy      Collio
# ...                    ...     ...    ...                 ...         ...
# 150928     Grand Brut Rosé      90   52.0           Champagne   Champagne
# 150929                 NaN      90   15.0  Northeastern Italy  Alto Adige
#
#        region_2             variety                winery
# 4           NaN  Provence red blend  Domaine de la Bégude
# ...

# %%
reviews.loc[reviews.price.notnull()]
# Out:
#        country                                        description  \
# 0           US  This tremendous 100% varietal wine hails from ...
# 1        Spain  Ripe aromas of fig, blackberry and cassis are ...
# ...        ...                                                ...
# 150928  France  A perfect salmon shade, with scents of peaches...
# 150929   Italy  More Pinot Grigios should taste like this. A r...
#
#                                  designation  points  price  \
# 0                          Martha's Vineyard      96  235.0
# 1       Carodorum Selección Especial Reserva      96  110.0
# ...                                      ...     ...    ...
# 150928                       Grand Brut Rosé      90   52.0
# 150929                                   NaN      90   15.0
#
#                   province     region_1 region_2             variety  \
# 0               California  Napa Valley     Napa  Cabernet Sauvignon
# ...

# %%
reviews['critic'] = 'everyone'
reviews['critic']
# Out:
# 0         everyone
# 1         everyone
#             ...
# 150928    everyone
# 150929    everyone
# Name: critic, Length: 150930, dtype: object

# %%
reviews['index_backwards'] = range(len(reviews), 0, -1)
reviews['index_backwards']
# Out:
# 0         150930
# 1         150929
#            ...
# 150928         2
# 150929         1
# Name: index_backwards, Length: 150930, dtype: int64

# %%
reviews = pd.read_csv('./winemag-data-130k-v2.csv', index_col='Unnamed: 0')
reviews
# Out:
#          country                                        description  \
# 0          Italy  Aromas include tropical fruit, broom, brimston...
# 1       Portugal  This is ripe and fruity, a wine that is smooth...
# ...          ...                                                ...
# 129969    France  A dry style of Pinot Gris, this is crisp with ...
# 129970    France  Big, rich and off-dry, this is powered by inte...
#
#                           designation  points  price           province  \
# 0                        Vulkà Bianco      87    NaN  Sicily & Sardinia
# 1                            Avidagos      87   15.0              Douro
# ...                               ...     ...    ...                ...
# 129969                            NaN      90   32.0             Alsace
# 129970  Lieu-dit Harth Cuvée Caroline      90   21.0             Alsace
#
#        region_1 region_2    taster_name taster_twitter_handle  \
# ...

# %%
reviews.head()
# Out:
#     country                                        description  \
# 0     Italy  Aromas include tropical fruit, broom, brimston...
# 1  Portugal  This is ripe and fruity, a wine that is smooth...
# 2        US  Tart and snappy, the flavors of lime flesh and...
# 3        US  Pineapple rind, lemon pith and orange blossom ...
# 4        US  Much like the regular bottling from 2012, this...
#
#                           designation  points  price           province  \
# 0                        Vulkà Bianco      87    NaN  Sicily & Sardinia
# 1                            Avidagos      87   15.0              Douro
# 2                                 NaN      87   14.0             Oregon
# 3                Reserve Late Harvest      87   13.0           Michigan
# 4  Vintner's Reserve Wild Child Block      87   65.0             Oregon
#
#               region_1           region_2         taster_name  \
# 0                 Etna                NaN       Kerin O’Keefe
# ...

# %%
decs = reviews['description']
decs
# Out:
# 0         Aromas include tropical fruit, broom, brimston...
# 1         This is ripe and fruity, a wine that is smooth...
#                                 ...
# 129969    A dry style of Pinot Gris, this is crisp with ...
# 129970    Big, rich and off-dry, this is powered by inte...
# Name: description, Length: 129971, dtype: object

# %%
first_description = decs[0]
first_description
# Out:
# "Aromas include tropical fruit, broom, brimstone and dried herb. The palate isn't overly expressive, offering unripened apple, citrus and dried sage alongside brisk acidity."

# %%
first_row = reviews.iloc[0]
first_row
# Out:
# country                                                    Italy
# description    Aromas include tropical fruit, broom, brimston...
#                                      ...
# variety                                              White Blend
# winery                                                   Nicosia
# Name: 0, Length: 13, dtype: object

# %%
first_descriptions = decs[0:10]
first_descriptions
# Out:
# 0    Aromas include tropical fruit, broom, brimston...
# 1    This is ripe and fruity, a wine that is smooth...
#                            ...
# 8    Savory dried thyme notes accent sunnier flavor...
# 9    This has great depth of flavor with its fresh ...
# Name: description, Length: 10, dtype: object

# %%
sample_reviews = reviews.iloc[[1, 2, 3, 5, 8]]
sample_reviews
# Out:
#     country                                        description  \
# 1  Portugal  This is ripe and fruity, a wine that is smooth...
# 2        US  Tart and snappy, the flavors of lime flesh and...
# 3        US  Pineapple rind, lemon pith and orange blossom ...
# 5     Spain  Blackberry and raspberry aromas show a typical...
# 8   Germany  Savory dried thyme notes accent sunnier flavor...
#
#             designation  points  price        province             region_1  \
# 1              Avidagos      87   15.0           Douro                  NaN
# 2                   NaN      87   14.0          Oregon    Willamette Valley
# 3  Reserve Late Harvest      87   13.0        Michigan  Lake Michigan Shore
# 5          Ars In Vitro      87   15.0  Northern Spain              Navarra
# 8                 Shine      87   12.0     Rheinhessen                  NaN
#
#             region_2         taster_name taster_twitter_handle  \
# ...

# %%
df = reviews.loc[[0, 1, 10, 100], ['country', 'province', 'region_1', 'region_2']]
df
# Out:
#       country           province      region_1      region_2
# 0       Italy  Sicily & Sardinia          Etna           NaN
# 1    Portugal              Douro           NaN           NaN
# 10         US         California   Napa Valley          Napa
# 100        US           New York  Finger Lakes  Finger Lakes

# %%
df = reviews.loc[0:99, ['country', 'variety']]
df
# Out:
#      country                   variety
# 0      Italy               White Blend
# 1   Portugal            Portuguese Red
# ..       ...                       ...
# 98     Italy                Sangiovese
# 99        US  Bordeaux-style Red Blend
#
# [100 rows x 2 columns]

# %%
italian_wines = reviews.loc[reviews['country'] == 'Italy']
italian_wines
# Out:
#        country                                        description  \
# 0        Italy  Aromas include tropical fruit, broom, brimston...
# 6        Italy  Here's a bright, informal red that opens with ...
# ...        ...                                                ...
# 129961   Italy  Intense aromas of wild cherry, baking spice, t...
# 129962   Italy  Blackberry, cassis, grilled herb and toasted a...
#
#                       designation  points  price           province  region_1  \
# 0                    Vulkà Bianco      87    NaN  Sicily & Sardinia      Etna
# 6                         Belsito      87   16.0  Sicily & Sardinia  Vittoria
# ...                           ...     ...    ...                ...       ...
# 129961                        NaN      90   30.0  Sicily & Sardinia   Sicilia
# 129962  Sàgana Tenuta San Giacomo      90   40.0  Sicily & Sardinia   Sicilia
#
#        region_2    taster_name taster_twitter_handle  \
# ...

# %%
top_oceania_wines = reviews.loc[((reviews['country'] == 'Australia') | (reviews['country'] == 'New Zealand')) & (reviews['points'] >= 95)]
top_oceania_wines
# Out:
#             country                                        description  \
# 345       Australia  This wine contains some material over 100 year...
# 346       Australia  This deep brown wine smells like a damp, mossy...
# ...             ...                                                ...
# 122507  New Zealand  This blend of Cabernet Sauvignon (62.5%), Merl...
# 122939    Australia  Full-bodied and plush yet vibrant and imbued w...
#
#                                   designation  points  price         province  \
# 345                                      Rare     100  350.0         Victoria
# 346                                      Rare      98  350.0         Victoria
# ...                                       ...     ...    ...              ...
# 122507  SQM Gimblett Gravels Cabernets/Merlot      95   79.0      Hawke's Bay
# 122939                             The Factor      98  125.0  South Australia
#
# ...

# %%
reviews
# Out:
#          country                                        description  \
# 0          Italy  Aromas include tropical fruit, broom, brimston...
# 1       Portugal  This is ripe and fruity, a wine that is smooth...
# ...          ...                                                ...
# 129969    France  A dry style of Pinot Gris, this is crisp with ...
# 129970    France  Big, rich and off-dry, this is powered by inte...
#
#                           designation  points  price           province  \
# 0                        Vulkà Bianco      87    NaN  Sicily & Sardinia
# 1                            Avidagos      87   15.0              Douro
# ...                               ...     ...    ...                ...
# 129969                            NaN      90   32.0             Alsace
# 129970  Lieu-dit Harth Cuvée Caroline      90   21.0             Alsace
#
#        region_1 region_2    taster_name taster_twitter_handle  \
# ...

# %%
reviews.points.describe()
# Out:
# count    129971.000000
# mean         88.447138
#              ...
# 75%          91.000000
# max         100.000000
# Name: points, Length: 8, dtype: float64

# %%
reviews.taster_name.describe()
# Out:
# count         103727
# unique            19
# top       Roger Voss
# freq           25514
# Name: taster_name, dtype: object

# %%
reviews.points.mean()
# Out:
# 88.44713820775404

# %%
reviews.taster_name.unique()
# Out:
# array(['Kerin O’Keefe', 'Roger Voss', 'Paul Gregutt',
#        'Alexander Peartree', 'Michael Schachner', 'Anna Lee C. Iijima',
#        'Virginie Boone', 'Matt Kettmann', nan, 'Sean P. Sullivan',
#        'Jim Gordon', 'Joe Czerwinski', 'Anne Krebiehl\xa0MW',
#        'Lauren Buzzeo', 'Mike DeSimone', 'Jeff Jenssen',
#        'Susan Kostrzewa', 'Carrie Dykes', 'Fiona Adams',
#        'Christina Pickard'], dtype=object)

# %%
reviews.taster_name.value_counts()
# Out:
# Roger Voss           25514
# Michael Schachner    15134
#                      ...
# Fiona Adams             27
# Christina Pickard        6
# Name: taster_name, Length: 19, dtype: int64

# %%
review_points_mean = reviews.points.mean()
reviews.points.map(lambda p : p - review_points_mean)
# Out:
# 0        -1.447138
# 1        -1.447138
#             ...
# 129969    1.552862
# 129970    1.552862
# Name: points, Length: 129971, dtype: float64

# %%
def remean_points(row):
    row.points = row.points - review_points_mean
    return row

reviews.apply(remean_points, axis=1)
# Out:
#          country                                        description  \
# 0          Italy  Aromas include tropical fruit, broom, brimston...
# 1       Portugal  This is ripe and fruity, a wine that is smooth...
# ...          ...                                                ...
# 129969    France  A dry style of Pinot Gris, this is crisp with ...
# 129970    France  Big, rich and off-dry, this is powered by inte...
#
#                           designation    points  price           province  \
# 0                        Vulkà Bianco -1.447138    NaN  Sicily & Sardinia
# 1                            Avidagos -1.447138   15.0              Douro
# ...                               ...       ...    ...                ...
# 129969                            NaN  1.552862   32.0             Alsace
# 129970  Lieu-dit Harth Cuvée Caroline  1.552862   21.0             Alsace
#
#        region_1 region_2    taster_name taster_twitter_handle  \
# ...

# %%
reviews.head(1)
# Out:
#   country                                        description   designation  \
# 0   Italy  Aromas include tropical fruit, broom, brimston...  Vulkà Bianco
#
#    points  price           province region_1 region_2    taster_name  \
# 0      87    NaN  Sicily & Sardinia     Etna      NaN  Kerin O’Keefe
#
#   taster_twitter_handle                              title      variety  \
# 0          @kerinokeefe  Nicosia 2013 Vulkà Bianco  (Etna)  White Blend
#
#     winery
# 0  Nicosia

# %%
reviews.points - review_points_mean
# Out:
# 0        -1.447138
# 1        -1.447138
#             ...
# 129969    1.552862
# 129970    1.552862
# Name: points, Length: 129971, dtype: float64

# %%
reviews.country + '-' + reviews.region_1
# Out:
# 0            Italy-Etna
# 1                   NaN
#               ...
# 129969    France-Alsace
# 129970    France-Alsace
# Length: 129971, dtype: object

# %%
median_points = reviews.points.mean()
median_points
# Out:
# 88.44713820775404

# %%
countries = reviews.country.unique()
countries
# Out:
# array(['Italy', 'Portugal', 'US', 'Spain', 'France', 'Germany',
#        'Argentina', 'Chile', 'Australia', 'Austria', 'South Africa',
#        'New Zealand', 'Israel', 'Hungary', 'Greece', 'Romania', 'Mexico',
#        'Canada', nan, 'Turkey', 'Czech Republic', 'Slovenia',
#        'Luxembourg', 'Croatia', 'Georgia', 'Uruguay', 'England',
#        'Lebanon', 'Serbia', 'Brazil', 'Moldova', 'Morocco', 'Peru',
#        'India', 'Bulgaria', 'Cyprus', 'Armenia', 'Switzerland',
#        'Bosnia and Herzegovina', 'Ukraine', 'Slovakia', 'Macedonia',
#        'China', 'Egypt'], dtype=object)

# %%
reviews_per_country = reviews.country.value_counts()
reviews_per_country
# Out:
# US        54504
# France    22093
#           ...
# China         1
# Egypt         1
# Name: country, Length: 43, dtype: int64

# %%
centered_price = reviews.price - reviews.price.mean()
centered_price
# Out:
# 0               NaN
# 1        -20.363389
#             ...
# 129969    -3.363389
# 129970   -14.363389
# Name: price, Length: 129971, dtype: float64

# %%
point_price_ratio = reviews.points / reviews.price
point_price_ratio
# Out:
# 0              NaN
# 1         5.800000
#             ...
# 129969    2.812500
# 129970    4.285714
# Length: 129971, dtype: float64

# %%
point_price_ratio_notna = point_price_ratio.dropna()
point_price_ratio_sorted = point_price_ratio_notna.sort_values(ascending=False)

# %%
point_price_ratio_sorted
# Out:
# 64590     21.500000
# 126096    21.500000
#             ...
# 15840      0.038400
# 80290      0.026667
# Length: 120975, dtype: float64

# %%
point_price_ratio_sorted.idxmax()
# Out:
# 64590

# %%
bergain_wine = reviews.title.loc[point_price_ratio_sorted.idxmax()]

# %%
reviews.description
# Out:
# 0         Aromas include tropical fruit, broom, brimston...
# 1         This is ripe and fruity, a wine that is smooth...
#                                 ...
# 129969    A dry style of Pinot Gris, this is crisp with ...
# 129970    Big, rich and off-dry, this is powered by inte...
# Name: description, Length: 129971, dtype: object

# %%
numberOfDescriptionsWithTropical = len(reviews.loc[reviews.description.map(lambda x: 'tropical' in x)])

# %%
numberOfDescriptionsWithFruity = len(reviews.loc[reviews.description.map(lambda x: 'fruity' in x)])

# %%
descriptor_counts = pd.Series([numberOfDescriptionsWithTropical, numberOfDescriptionsWithFruity], index=['tropical', 'fruity'])
descriptor_counts
# Out:
# tropical    3607
# fruity      9090
# dtype: int64

# %%
reviews
# Out:
#          country                                        description  \
# 0          Italy  Aromas include tropical fruit, broom, brimston...
# 1       Portugal  This is ripe and fruity, a wine that is smooth...
# ...          ...                                                ...
# 129969    France  A dry style of Pinot Gris, this is crisp with ...
# 129970    France  Big, rich and off-dry, this is powered by inte...
#
#                           designation  points  price           province  \
# 0                        Vulkà Bianco      87    NaN  Sicily & Sardinia
# 1                            Avidagos      87   15.0              Douro
# ...                               ...     ...    ...                ...
# 129969                            NaN      90   32.0             Alsace
# 129970  Lieu-dit Harth Cuvée Caroline      90   21.0             Alsace
#
#        region_1 region_2    taster_name taster_twitter_handle  \
# ...

# %%
def stars(row):
    if row.country == 'Canada':
        return 3
    elif row.points >= 95:
        return 3
    elif row.points >= 85:
        return 2
    else:
        return 1

star_ratings = reviews.apply(stars, axis='columns')
star_ratings
# Out:
# 0         2
# 1         2
#          ..
# 129969    2
# 129970    2
# Length: 129971, dtype: int64

# %%
reviews.groupby('points').points.count()
# Out:
# points
# 80     397
# 81     692
#       ...
# 99      33
# 100     19
# Name: points, Length: 21, dtype: int64

# %%
reviews.points.value_counts()
# Out:
# 88     17207
# 87     16933
#        ...
# 99        33
# 100       19
# Name: points, Length: 21, dtype: int64

# %%
reviews.groupby('points').price.min()
# Out:
# points
# 80      5.0
# 81      5.0
#        ...
# 99     44.0
# 100    80.0
# Name: price, Length: 21, dtype: float64

# %%
reviews.groupby('winery').apply(lambda df: df.title.iloc[0])
# Out:
# winery
# 1+1=3                          1+1=3 NV Rosé Sparkling (Cava)
# 10 Knots                 10 Knots 2010 Viognier (Paso Robles)
#                                   ...
# àMaurice    àMaurice 2013 Fred Estate Syrah (Walla Walla V...
# Štoka                         Štoka 2009 Izbrani Teran (Kras)
# Length: 16757, dtype: object

# %%
reviews.groupby(['country', 'province']).apply(lambda df: df.loc[df.points.idxmax()])
# Out:
#                               country  \
# country   province
# Argentina Mendoza Province  Argentina
#           Other             Argentina
# ...                               ...
# Uruguay   San Jose            Uruguay
#           Uruguay             Uruguay
#
#                                                                   description  \
# country   province
# Argentina Mendoza Province  If the color doesn't tell the full story, the ...
#           Other             Take note, this could be the best wine Colomé ...
# ...                                                                       ...
# Uruguay   San Jose          Baked, sweet, heavy aromas turn earthy with ti...
#           Uruguay           Cherry and berry aromas are ripe, healthy and ...
#
#                                           designation  points  price  \
# country   province
# Argentina Mendoza Province           Nicasia Vineyard      97  120.0
# ...

# %%
reviews.groupby(['country']).price.agg([len, min, max])
# Out:
#             len   min    max
# country
# Argentina  3800   4.0  230.0
# Armenia       2  14.0   15.0
# ...         ...   ...    ...
# Ukraine      14   6.0   13.0
# Uruguay     109  10.0  130.0
#
# [43 rows x 3 columns]

# %%
countries_reviewed = reviews.groupby(['country', 'province']).description.agg([len]) 
countries_reviewed
# Out:
#                              len
# country   province
# Argentina Mendoza Province  3264
#           Other              536
# ...                          ...
# Uruguay   San Jose             3
#           Uruguay             24
#
# [425 rows x 1 columns]

# %%
type(countries_reviewed.index)
# Out:
# pandas.core.indexes.multi.MultiIndex

# %%
countries_reviewed = countries_reviewed.reset_index()
countries_reviewed.sort_values(by='len', ascending=False)
# Out:
#     country    province    len
# 392      US  California  36247
# 415      US  Washington   8639
# ..      ...         ...    ...
# 63    Chile     Coelemu      1
# 149  Greece      Beotia      1
#
# [425 rows x 3 columns]

# %%
countries_reviewed.sort_index()
# Out:
#        country          province   len
# 0    Argentina  Mendoza Province  3264
# 1    Argentina             Other   536
# ..         ...               ...   ...
# 423    Uruguay          San Jose     3
# 424    Uruguay           Uruguay    24
#
# [425 rows x 3 columns]

# %%
countries_reviewed.sort_values(by=['country', 'len'])
# Out:
#        country          province   len
# 1    Argentina             Other   536
# 0    Argentina  Mendoza Province  3264
# ..         ...               ...   ...
# 424    Uruguay           Uruguay    24
# 419    Uruguay         Canelones    43
#
# [425 rows x 3 columns]

# %%
reviews_written = reviews.groupby('taster_twitter_handle').taster_twitter_handle.count()

# %%
best_rating_per_price = reviews.groupby('price').points.max().sort_index()

# %%
price_extremes = reviews.groupby('variety').price.agg([min, max])

# %%
sorted_varieties = reviews.groupby('variety').price.agg([min, max]).sort_values(by=['min', 'max'], ascending=False)

# %%
reviewer_mean_ratings = reviews.groupby('taster_name').points.mean()

# %%
reviewer_mean_ratings.describe()
# Out:
# count    19.000000
# mean     88.233026
#            ...
# 75%      88.975256
# max      90.562551
# Name: points, Length: 8, dtype: float64

# %%
reviews.groupby(['country', 'variety']).size().sort_values(ascending=False)
# Out:
# country  variety
# US       Pinot Noir            9885
#          Cabernet Sauvignon    7315
#                                ...
# Mexico   Rosado                   1
# Uruguay  White Blend              1
# Length: 1612, dtype: int64

# %%
reviews[pd.isnull(reviews.country)]
# Out:
#        country                                        description  \
# 913        NaN  Amber in color, this wine has aromas of peach ...
# 3131       NaN  Soft, fruity and juicy, this is a pleasant, si...
# ...        ...                                                ...
# 129590     NaN  A blend of 60% Syrah, 30% Cabernet Sauvignon a...
# 129900     NaN  This wine offers a delightful bouquet of black...
#
#            designation  points  price province region_1 region_2  \
# 913     Asureti Valley      87   30.0      NaN      NaN      NaN
# 3131          Partager      83    NaN      NaN      NaN      NaN
# ...                ...     ...    ...      ...      ...      ...
# 129590            Shah      90   30.0      NaN      NaN      NaN
# 129900             NaN      91   32.0      NaN      NaN      NaN
#
#           taster_name taster_twitter_handle  \
# 913     Mike DeSimone        @worldwineguys
# 3131       Roger Voss            @vossroger
# ...

# %%
reviews.region_2.fillna('Unknown')
# Out:
# 0         Unknown
# 1         Unknown
#            ...
# 129969    Unknown
# 129970    Unknown
# Name: region_2, Length: 129971, dtype: object

# %%
reviews.taster_twitter_handle.replace('@kerinokeefe', '@kerino')
# Out:
# 0            @kerino
# 1         @vossroger
#              ...
# 129969    @vossroger
# 129970    @vossroger
# Name: taster_twitter_handle, Length: 129971, dtype: object

# %%
dtype = reviews.points.dtype

# %%
points_strings = reviews.points.astype('str')

# %%
n_missing_prices = reviews.price.isnull().sum()

# %%
reviews_replaced = reviews.fillna('Unknown')
reviews_replaced.groupby('region_1')['region_1'].count().sort_values(ascending=False)
# Out:
# region_1
# Unknown                      21247
# Napa Valley                   4480
#                              ...
# Frascati                         1
# Dolcetto d'Alba Superiore        1
# Name: region_1, Length: 1230, dtype: int64

# %%
reviews.rename(columns={'points': 'score'})
# Out:
#          country                                        description  \
# 0          Italy  Aromas include tropical fruit, broom, brimston...
# 1       Portugal  This is ripe and fruity, a wine that is smooth...
# ...          ...                                                ...
# 129969    France  A dry style of Pinot Gris, this is crisp with ...
# 129970    France  Big, rich and off-dry, this is powered by inte...
#
#                           designation  score  price           province  \
# 0                        Vulkà Bianco     87    NaN  Sicily & Sardinia
# 1                            Avidagos     87   15.0              Douro
# ...                               ...    ...    ...                ...
# 129969                            NaN     90   32.0             Alsace
# 129970  Lieu-dit Harth Cuvée Caroline     90   21.0             Alsace
#
#        region_1 region_2    taster_name taster_twitter_handle  \
# 0          Etna      NaN  Kerin O’Keefe          @kerinokeefe
# ...

# %%
reviews.rename(index={0: 'firstEntry', 1: 'secondEntry'})
# Out:
#               country                                        description  \
# firstEntry      Italy  Aromas include tropical fruit, broom, brimston...
# secondEntry  Portugal  This is ripe and fruity, a wine that is smooth...
# ...               ...                                                ...
# 129969         France  A dry style of Pinot Gris, this is crisp with ...
# 129970         France  Big, rich and off-dry, this is powered by inte...
#
#                                designation  points  price           province  \
# firstEntry                    Vulkà Bianco      87    NaN  Sicily & Sardinia
# secondEntry                       Avidagos      87   15.0              Douro
# ...                                    ...     ...    ...                ...
# 129969                                 NaN      90   32.0             Alsace
# 129970       Lieu-dit Harth Cuvée Caroline      90   21.0             Alsace
#
# ...

# %%
reviews.rename_axis('wines', axis='rows').rename_axis('fields', axis='columns')
# Out:
# fields   country                                        description  \
# wines
# 0          Italy  Aromas include tropical fruit, broom, brimston...
# 1       Portugal  This is ripe and fruity, a wine that is smooth...
# ...          ...                                                ...
# 129969    France  A dry style of Pinot Gris, this is crisp with ...
# 129970    France  Big, rich and off-dry, this is powered by inte...
#
# fields                    designation  points  price           province  \
# wines
# 0                        Vulkà Bianco      87    NaN  Sicily & Sardinia
# 1                            Avidagos      87   15.0              Douro
# ...                               ...     ...    ...                ...
# 129969                            NaN      90   32.0             Alsace
# 129970  Lieu-dit Harth Cuvée Caroline      90   21.0             Alsace
#
# fields region_1 region_2    taster_name taster_twitter_handle  \
# wines
# ...

# %%
canadian_youtube = pd.read_csv('./CAvideos.csv')
british_youtube = pd.read_csv('./GBvideos.csv')
pd.concat([canadian_youtube, british_youtube])
# Out:
#           video_id trending_date  \
# 0      n1WpP7iowLc      17.14.11
# 1      0dBIkQ4Mz1M      17.14.11
# ...            ...           ...
# 38914  -DRsfNObKIQ      18.14.06
# 38915  4YFo4bdMO8Q      18.14.06
#
#                                                    title  \
# 0             Eminem - Walk On Water (Audio) ft. Beyoncé
# 1                          PLUSH - Bad Unboxing Fan Mail
# ...                                                  ...
# 38914  Eleni Foureira - Fuego - Cyprus - LIVE - First...
# 38915  KYLE - Ikuyo feat.  2 Chainz & Sophia Black [A...
#
#                  channel_title  category_id              publish_time  \
# 0                   EminemVEVO           10  2017-11-10T17:00:03.000Z
# 1                    iDubbbzTV           23  2017-11-13T17:00:00.000Z
# ...                        ...          ...                       ...
# 38914  Eurovision Song Contest           24  2018-05-08T20:32:32.000Z
# ...

# %%
left = canadian_youtube.set_index(['title', 'trending_date'])
right = british_youtube.set_index(['title', 'trending_date'])
left.join(right, lsuffix='_CAN', rsuffix='_UK')
# Out:
#                                                                  video_id_CAN  \
# title                                              trending_date
# !! THIS VIDEO IS NOTHING BUT PAIN !! | Getting ... 18.04.01       PNn8sECd7io
# #1 Fortnite World Rank - 2,323 Solo Wins!          18.09.03       DvPW66IFhMI
# ...                                                                       ...
# 🚨 BREAKING NEWS 🔴 Raja Live all Slot Channels W... 18.07.05       Wt9Gkpmbt44
# 🚨Active Shooter at YouTube Headquarters - LIVE ... 18.04.04       Az72jrKbANA
#
#                                                                                 channel_title_CAN  \
# title                                              trending_date
# !! THIS VIDEO IS NOTHING BUT PAIN !! | Getting ... 18.04.01                            Markiplier
# #1 Fortnite World Rank - 2,323 Solo Wins!          18.09.03                        AlexRamiGaming
# ...

# %%
reviews.head()
# Out:
#     country                                        description  \
# 0     Italy  Aromas include tropical fruit, broom, brimston...
# 1  Portugal  This is ripe and fruity, a wine that is smooth...
# 2        US  Tart and snappy, the flavors of lime flesh and...
# 3        US  Pineapple rind, lemon pith and orange blossom ...
# 4        US  Much like the regular bottling from 2012, this...
#
#                           designation  points  price           province  \
# 0                        Vulkà Bianco      87    NaN  Sicily & Sardinia
# 1                            Avidagos      87   15.0              Douro
# 2                                 NaN      87   14.0             Oregon
# 3                Reserve Late Harvest      87   13.0           Michigan
# 4  Vintner's Reserve Wild Child Block      87   65.0             Oregon
#
#               region_1           region_2         taster_name  \
# 0                 Etna                NaN       Kerin O’Keefe
# ...

# %%
renamed = reviews.rename(columns={'region_1': 'region', 'region_2': 'locale'})

# %%
reindexed = reviews.rename_axis('wines', axis='rows')

# %% [markdown]
# The datasets in the next two exercises have changed thus cant be done herre
