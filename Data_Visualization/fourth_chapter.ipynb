# %%
import pandas as pd
pd.plotting.register_matplotlib_converters()
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
insurance_data = pd.read_csv('./insurance.csv')
insurance_data
# Out:
#       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1338 rows x 7 columns]

# %%
sns.scatterplot(x=insurance_data['bmi'], y=insurance_data['charges'])
# Out:
# <AxesSubplot:xlabel='bmi', ylabel='charges'>

# %%
sns.regplot(x=insurance_data['bmi'], y=insurance_data['charges'])
# Out:
# <AxesSubplot:xlabel='bmi', ylabel='charges'>

# %%
sns.scatterplot(x=insurance_data['bmi'], y=insurance_data['charges'], hue=insurance_data['smoker'])
# Out:
# <AxesSubplot:xlabel='bmi', ylabel='charges'>

# %%
sns.lmplot(x='bmi', y='charges', hue='smoker', data=insurance_data)

# %%
sns.swarmplot(x=insurance_data['smoker'], y=insurance_data['charges'])
# Out:
# /home/thomas/anaconda3/lib/python3.9/site-packages/seaborn/categorical.py:1296: UserWarning: 60.8% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# <AxesSubplot:xlabel='smoker', ylabel='charges'>

# %%
candy_data = pd.read_csv('./candy.csv', index_col='id')
candy_data
# Out:
#                 competitorname chocolate fruity caramel peanutyalmondy nougat  \
# id
# 0                    100 Grand       Yes     No     Yes             No     No
# 1                 3 Musketeers       Yes     No      No             No    Yes
# 2                    Air Heads        No    Yes      No             No     No
# 3                   Almond Joy       Yes     No      No            Yes     No
# 4                    Baby Ruth       Yes     No     Yes            Yes    Yes
# ..                         ...       ...    ...     ...            ...    ...
# 78                   Twizzlers        No    Yes      No             No     No
# 79                    Warheads        No    Yes      No             No     No
# 80        Welch's Fruit Snacks        No    Yes      No             No     No
# 81  Werther's Original Caramel        No     No     Yes             No     No
# 82                    Whoppers       Yes     No      No             No     No
#
# ...

# %%
first_five_winpercent = candy_data.head()[['competitorname', 'winpercent']].sort_values(by='winpercent', ascending=False)
first_five_winpercent
# Out:
#    competitorname  winpercent
# id
# 1    3 Musketeers   67.602936
# 0       100 Grand   66.971725
# 4       Baby Ruth   56.914547
# 2       Air Heads   52.341465
# 3      Almond Joy   50.347546

# %%
just_the_two = first_five_winpercent.loc[(first_five_winpercent['competitorname'] == '3 Musketeers') | (first_five_winpercent['competitorname'] == 'Almond Joy')]
just_the_two
# Out:
#    competitorname  winpercent
# id
# 1    3 Musketeers   67.602936
# 3      Almond Joy   50.347546

# %%
just_the_two.iloc[0][0]
# Out:
# '3 Musketeers'

# %%
candy_data[['competitorname', 'sugarpercent']].loc[(candy_data['competitorname'] == 'Air Heads') | (candy_data['competitorname'] == 'Baby Ruth')].sort_values(by='sugarpercent', ascending=False).iloc[0][0]
# Out:
# 'Air Heads'

# %%
sns.scatterplot(x=candy_data['sugarpercent'], y=candy_data['winpercent'])
# Out:
# <AxesSubplot:xlabel='sugarpercent', ylabel='winpercent'>

# %%
sns.regplot(x=candy_data['sugarpercent'], y=candy_data['winpercent'])
# Out:
# <AxesSubplot:xlabel='sugarpercent', ylabel='winpercent'>

# %%
sns.scatterplot(x=candy_data['pricepercent'], y=candy_data['winpercent'], hue=candy_data['chocolate'])
# Out:
# <AxesSubplot:xlabel='pricepercent', ylabel='winpercent'>

# %%
sns.lmplot(x='pricepercent', y='winpercent', hue='chocolate', data=candy_data)

# %%
sns.swarmplot(x=candy_data['chocolate'], y=candy_data['winpercent'])
# Out:
# <AxesSubplot:xlabel='chocolate', ylabel='winpercent'>
