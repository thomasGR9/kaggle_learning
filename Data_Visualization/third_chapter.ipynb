# %%
import pandas as pd
pd.plotting.register_matplotlib_converters()
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
flight_data = pd.read_csv('./flight_delays.csv', index_col='Month')
flight_data
# Out:
#              AA        AS         B6        DL         EV         F9  \
# Month
# 1      6.955843 -0.320888   7.347281 -2.043847   8.537497  18.357238
# 2      7.530204 -0.782923  18.657673  5.614745  10.417236  27.424179
# 3      6.693587 -0.544731  10.741317  2.077965   6.730101  20.074855
# 4      4.931778 -3.009003   2.780105  0.083343   4.821253  12.640440
# 5      5.173878 -1.716398  -0.709019  0.149333   7.724290  13.007554
# 6      8.191017 -0.220621   5.047155  4.419594  13.952793  19.712951
# 7      3.870440  0.377408   5.841454  1.204862   6.926421  14.464543
# 8      3.193907  2.503899   9.280950  0.653114   5.154422   9.175737
# 9     -1.432732 -1.813800   3.539154 -3.703377   0.851062   0.978460
# 10    -0.580930 -2.993617   3.676787 -5.011516   2.303760   0.082127
# 11     0.772630 -1.916516   1.418299 -3.175414   4.415930  11.164527
# 12     4.149684 -1.846681  13.839290  2.504595   6.685176   9.346221
#
# ...

# %%
plt.figure(figsize=(10, 6))
plt.title('Average Arrival Delay for Spirit Airlines Flights By Month')
sns.barplot(x=flight_data.index, y=flight_data['NK'])
plt.ylabel('Arrival delay(minutes)')
# Out:
# Text(0, 0.5, 'Arrival delay(minutes)')

# %%
plt.figure(figsize=(14, 7))
plt.title('Average Arrival Delay for Each Airline, by Month')
sns.heatmap(data=flight_data, annot=True)
plt.xlabel('Airline')
# Out:
# Text(0.5, 47.7222222222222, 'Airline')

# %%
ign_data = pd.read_csv('./ign_scores.csv')
ign_data
# Out:
#                 Platform    Action  Action, Adventure  Adventure  Fighting  \
# 0              Dreamcast  6.882857           7.511111   6.281818  8.200000
# 1       Game Boy Advance  6.373077           7.507692   6.057143  6.226316
# 2         Game Boy Color  6.272727           8.166667   5.307692  4.500000
# 3               GameCube  6.532584           7.608333   6.753846  7.422222
# 4           Nintendo 3DS  6.670833           7.481818   7.414286  6.614286
# 5            Nintendo 64  6.649057           8.250000   7.000000  5.681250
# 6            Nintendo DS  5.903608           7.240000   6.259804  6.320000
# 7           Nintendo DSi  6.827027           8.500000   6.090909  7.500000
# 8                     PC  6.805791           7.334746   7.136798  7.166667
# 9            PlayStation  6.016406           7.933333   6.313725  6.553731
# 10         PlayStation 2  6.467361           7.250000   6.315152  7.306349
# ...

# %%
PC_data = ign_data.loc[ign_data['Platform'] == 'PC'].loc[:, 'Action':]

# %%
PC_data.T.max().values[0]
# Out:
# 7.759930313588847

# %%
Playstation_Vita_data = ign_data.loc[ign_data['Platform'] == 'PlayStation Vita'].loc[:, 'Action':]
Playstation_Vita_data
# Out:
#       Action  Action, Adventure  Adventure  Fighting  Platformer  Puzzle  \
# 14  7.173077           6.133333   8.057143  7.527273     8.56875    8.25
#
#        RPG  Racing  Shooter  Simulation  Sports  Strategy
# 14  7.3375     6.3     7.66       5.725    7.13       8.9

# %%
Playstation_Vita_data.min(axis=1).to_list()
# Out:
# [5.725]

# %%
Playstation_Vita_data['Simulation'].to_list()
# Out:
# [5.725]

# %%
Playstation_Vita_data.columns
# Out:
# Index(['Action', 'Action, Adventure', 'Adventure', 'Fighting', 'Platformer',
#        'Puzzle', 'RPG', 'Racing', 'Shooter', 'Simulation', 'Sports',
#        'Strategy'],
#       dtype='object')

# %%
for col in Playstation_Vita_data.columns:
   if ((Playstation_Vita_data[col].tolist()) == (Playstation_Vita_data.min(axis=1).to_list())):
     print("\'{}\'".format(col))
# Out:
# 'Simulation'

# %%
for col in Playstation_Vita_data.columns:
   if ((Playstation_Vita_data[col].tolist()) == (Playstation_Vita_data.min(axis=1).to_list())):
     X = col

# %%
X
# Out:
# 'Simulation'

# %%
ign_data['Racing']
# Out:
# 0     7.042500
# 1     6.657143
# 2     5.897436
# 3     6.852632
# 4     6.900000
# 5     6.939623
# 6     6.038636
# 7     6.563636
# 8     7.032418
# 9     6.773387
# 10    6.585065
# 11    6.978571
# 12    7.590000
# 13    6.401961
# 14    6.300000
# 15    5.011667
# 16    6.898305
# 17    7.021591
# 18    6.996154
# 19    8.163636
# 20    7.315789
# Name: Racing, dtype: float64

# %%
sns.barplot(y=ign_data['Platform'], x=ign_data['Racing'])
# Out:
# <AxesSubplot:xlabel='Racing', ylabel='Platform'>

# %%
ign_data_new = pd.read_csv('./ign_scores.csv', index_col=['Platform'])
ign_data_new
# Out:
#                         Action  Action, Adventure  Adventure  Fighting  \
# Platform
# Dreamcast             6.882857           7.511111   6.281818  8.200000
# Game Boy Advance      6.373077           7.507692   6.057143  6.226316
# Game Boy Color        6.272727           8.166667   5.307692  4.500000
# GameCube              6.532584           7.608333   6.753846  7.422222
# Nintendo 3DS          6.670833           7.481818   7.414286  6.614286
# Nintendo 64           6.649057           8.250000   7.000000  5.681250
# Nintendo DS           5.903608           7.240000   6.259804  6.320000
# Nintendo DSi          6.827027           8.500000   6.090909  7.500000
# PC                    6.805791           7.334746   7.136798  7.166667
# PlayStation           6.016406           7.933333   6.313725  6.553731
# PlayStation 2         6.467361           7.250000   6.315152  7.306349
# PlayStation 3         6.853819           7.306154   6.820988  7.710938
# ...

# %%
sns.heatmap(data=ign_data_new, annot=True)
# Out:
# <AxesSubplot:ylabel='Platform'>
