# %%
import pandas as pd
pd.plotting.register_matplotlib_converters()
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
iris_data = pd.read_csv('./iris.csv', index_col='Id')
iris_data
# Out:
#      Sepal Length (cm)  Sepal Width (cm)  Petal Length (cm)  Petal Width (cm)  \
# Id
# 1                  5.1               3.5                1.4               0.2
# 2                  4.9               3.0                1.4               0.2
# 3                  4.7               3.2                1.3               0.2
# 4                  4.6               3.1                1.5               0.2
# 5                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 146                6.7               3.0                5.2               2.3
# 147                6.3               2.5                5.0               1.9
# 148                6.5               3.0                5.2               2.0
# 149                6.2               3.4                5.4               2.3
# 150                5.9               3.0                5.1               1.8
#
#             Species
# Id
# ...

# %%
sns.histplot(iris_data['Petal Length (cm)'])
# Out:
# <AxesSubplot:xlabel='Petal Length (cm)', ylabel='Count'>

# %%
sns.kdeplot(data=iris_data['Petal Length (cm)'], shade=True)
# Out:
# <AxesSubplot:xlabel='Petal Length (cm)', ylabel='Density'>

# %%
sns.jointplot(x=iris_data['Petal Length (cm)'], y=iris_data['Petal Width (cm)'], kind='kde')

# %%
sns.histplot(data=iris_data, x='Petal Length (cm)', hue='Species')
# Out:
# <AxesSubplot:xlabel='Petal Length (cm)', ylabel='Count'>

# %%
sns.kdeplot(data=iris_data, x='Petal Length (cm)', hue='Species', shade=True)
# Out:
# <AxesSubplot:xlabel='Petal Length (cm)', ylabel='Density'>

# %%
cancer_data = pd.read_csv('./cancer.csv', index_col='Id')
cancer_data
# Out:
#          Diagnosis  Radius (mean)  Texture (mean)  Perimeter (mean)  \
# Id
# 8510426          B         13.540           14.36             87.46
# 8510653          B         13.080           15.71             85.63
# 8510824          B          9.504           12.44             60.34
# 854941           B         13.030           18.42             82.61
# 85713702         B          8.196           16.84             51.71
# ...            ...            ...             ...               ...
# 926125           M         20.920           25.09            143.00
# 926424           M         21.560           22.39            142.00
# 926682           M         20.130           28.25            131.20
# 926954           M         16.600           28.08            108.30
# 927241           M         20.600           29.33            140.10
#
#           Area (mean)  Smoothness (mean)  Compactness (mean)  \
# Id
# 8510426         566.3            0.09779             0.08129
# ...

# %%
cancer_data['Perimeter (mean)'].max()
# Out:
# 188.5

# %%
cancer_data
# Out:
#          Diagnosis  Radius (mean)  Texture (mean)  Perimeter (mean)  \
# Id
# 8510426          B         13.540           14.36             87.46
# 8510653          B         13.080           15.71             85.63
# 8510824          B          9.504           12.44             60.34
# 854941           B         13.030           18.42             82.61
# 85713702         B          8.196           16.84             51.71
# ...            ...            ...             ...               ...
# 926125           M         20.920           25.09            143.00
# 926424           M         21.560           22.39            142.00
# 926682           M         20.130           28.25            131.20
# 926954           M         16.600           28.08            108.30
# 927241           M         20.600           29.33            140.10
#
#           Area (mean)  Smoothness (mean)  Compactness (mean)  \
# Id
# 8510426         566.3            0.09779             0.08129
# ...

# %%
cancer_data['Radius (mean)'][8510824]
# Out:
# 9.504

# %%
sns.histplot(x=cancer_data['Area (mean)'], hue=cancer_data['Diagnosis'])
# Out:
# <AxesSubplot:xlabel='Area (mean)', ylabel='Count'>

# %%
sns.jointplot(x=cancer_data['Radius (worst)'], y=cancer_data['Diagnosis'])

# %%
sns.jointplot(x=cancer_data['Radius (worst)'])
